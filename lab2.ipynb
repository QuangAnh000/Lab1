# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('D:\lab2\processed_dulieuxettuyendaihoc.csv')

# %%
data.head(5)
# Out:
#    STT  T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   D6   N6  GT  DT  \
# 0    1 NaN  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.6  5.9   F NaN
# 1    2 NaN  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.1  4.4   M NaN
# 2    3 NaN  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  8.1  4.6   M NaN
# 3    4 NaN  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  7.3  7.4   M NaN
# 4    5 NaN  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  7.5  7.2   M NaN
#
#     KV   DH1   DH2   DH3  KT  KQXT
# 0  2NT  3.25  3.25  4.50  A1     0
# 1    1  6.00  4.00  3.50   C     0
# 2    1  5.00  6.75  4.00   C     1
# 3    1  4.25  4.25  5.25  D1     0
# 4  2NT  4.25  4.50  5.00   A     0
#
# [5 rows x 57 columns]

# %%
data.tail(5)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   D6   N6  GT  DT  \
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  6.1  6.2   F NaN
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  7.5  4.4   F NaN
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  8.4  5.8   M NaN
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  5.2  5.9   M NaN
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  6.6  5.8   M NaN
#
#      KV   DH1   DH2   DH3  KT  KQXT
# 95    1  5.25  1.50  6.25   C     0
# 96    1  5.25  3.75  4.75   C     0
# 97  2NT  7.00  8.00  4.00   C     1
# 98    1  5.00  3.50  5.50   C     0
# 99  2NT  5.25  2.50  4.25   C     0
#
# [5 rows x 57 columns]

# %%
def get_mean(scores):
    return sum(scores)/len(scores)

# %%
result=data["DH1"].sum()
result
# Out:
# 374.0

# %%
def Q1(g):
    return np.percentile(g,50)

# %%
def Q2(g):
    return np.percentile(g,25)

# %%
def std(g):
    return np.std(g)

# %%
pd.pivot_table(data=data,index='KT',values='DH1',aggfunc=["sum","mean","median","min","max","std"])
# Out:
#        sum      mean median   min   max       std
#        DH1       DH1    DH1   DH1   DH1       DH1
# KT
# A   163.50  3.336735   3.25  1.00  6.50  1.274296
# A1   17.50  2.916667   3.00  2.00  4.25  0.861201
# B    29.50  3.277778   3.50  1.75  4.50  0.823905
# C    79.25  5.660714   5.25  4.75  7.00  0.812209
# D1   84.25  3.829545   3.75  1.25  6.75  1.370146

# %%
pd.pivot_table(data=data,index='KT',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
# Out:
#        sum      mean median   min  max       std
#        DH2       DH2    DH2   DH2  DH2       DH2
# KT
# A   212.00  4.326531  4.500  2.50  6.5  0.792550
# A1   25.50  4.250000  4.250  3.25  5.5  0.836660
# B    44.00  4.888889  4.750  3.75  6.0  0.839560
# C    59.25  4.232143  3.875  1.50  8.0  1.947544
# D1   84.75  3.852273  3.750  2.25  6.5  0.850977

# %%
pd.pivot_table(data=data,index='KT',values='DH2',aggfunc=["sum","mean","median","min","max","std"])

# %%
pd.pivot_table(data=data,index='KT',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
pd.pivot_table(data=data,index='KV',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
# Out:
#         sum      mean median  min   max       std
#         DH2       DH2    DH2  DH2   DH2       DH2
# KV
# 1    243.25  4.054167    4.0  1.5  6.75  1.023135
# 2     86.75  4.565789    4.5  3.5  6.75  1.013253
# 2NT   95.50  4.547619    4.5  2.5  8.00  1.116969

# %%
pd.pivot_table(data=data,index='KT',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
pd.pivot_table(data=data,index='KV',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
pd.pivot_table(data=data,index='DT',values='DH2',aggfunc=["sum","mean","median","min","max","std"])
# Out:
#       sum  mean median   min   max       std
#       DH2   DH2    DH2   DH2   DH2       DH2
# DT
# 1.0  7.50  3.75   3.75  3.50  4.00  0.353553
# 6.0  3.75  3.75   3.75  3.75  3.75       NaN

# %%
gf=data.groupby("GT")["GT"].agg("count")

# %%
gf.plot.bar()
# Out:
# <AxesSubplot:xlabel='GT'>

# %%
gf.plot.pie()
# Out:
# <AxesSubplot:ylabel='GT'>
